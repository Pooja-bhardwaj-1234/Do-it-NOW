# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\pbbha\\OneDrive\\Desktop\\Term 4\\HRA\\4 Regression.xlsx")

# %%
import statsmodels.api as sm
x=df['Hours_of _Tr']
y=df['Productivity']

# %%
x=sm.add_constant(x)
model1=sm.OLS(y,x)

# %%
result=model1.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Productivity   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.053
# Method:                 Least Squares   F-statistic:                   0.05095
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):              0.824
# Time:                        12:42:19   Log-Likelihood:                -92.988
# No. Observations:                  20   AIC:                             190.0
# Df Residuals:                      18   BIC:                             192.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           58.1799     13.682      4.252      0.000      29.435      86.925
# ...

# %%
df=pd.read_excel('C:\\Users\\pbbha\\OneDrive\\Desktop\\Term 4\\HRA\\mean median mode - Original.xlsx')

# %%
df
# Out:
#       age              department  employee_number  gender  job_level  \
# 0      41                   Sales                1  Female          2
# 1      49  Research & Development                2    Male          2
# 2      37  Research & Development                4    Male          1
# 3      33  Research & Development                5  Female          1
# 4      27  Research & Development                7    Male          1
# ...   ...                     ...              ...     ...        ...
# 1465   36  Research & Development             2061    Male          2
# 1466   39  Research & Development             2062    Male          3
# 1467   27  Research & Development             2064    Male          2
# 1468   49                   Sales             2065    Male          2
# 1469   34  Research & Development             2068    Male          2
#
#      marital_status over_time  performance_rating  totalW_working_years  \
# ...

# %%
import statsmodels.api as sm1
x=df['performance_rating']
y=df['percent_hike']

# %%
x=sm1.add_constant(x)
model2=sm1.OLS(y,x)

# %%
result=model2.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           percent_hike   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     2187.
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          4.27e-293
# Time:                        12:42:23   Log-Likelihood:                -3322.1
# No. Observations:                1470   AIC:                             6648.
# Df Residuals:                    1468   BIC:                             6659.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -9.5358      0.533    -17.905      0.000     -10.580      -8.491
# ...

# %%
# null - no relationship
# alternative= relationship
# here p - value is low we failed to reject null hypothesis.
#OLS = Trendline
#There is a relationship between these 2 variables 
# If R-square is more than .7 there is strong relation

# %%
df1=df.drop(['percent_hike'],axis=1)

# %%
#Depnedent Variable will be 1 only = y
#Independent Variable can be more than 1 = x

# %%
x=df1
y=df['percent_hike']

# %%
# Convert categorical variables to dummy variables
df_dummies = pd.get_dummies(df, columns=['department', 'gender', 'marital_status', 'over_time'], drop_first=True)

# After one-hot encoding, drop the 'percent_hike' column for the predictors (X)
x = df_dummies.drop(['percent_hike'], axis=1)

# Target remains the same
y = df['percent_hike']

# Add constant to the predictors
x = sm.add_constant(x)

# Run the regression
model1 = sm.OLS(y, x).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           percent_hike   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     283.4
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):               0.00
# Time:                        13:38:31   Log-Likelihood:                -2884.5
# No. Observations:                1470   AIC:                             5807.
# Df Residuals:                    1451   BIC:                             5908.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...
